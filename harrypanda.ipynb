# %% [markdown]
# <a href="https://colab.research.google.com/github/lavanyasrii/lavanyasrii/blob/main/harrypanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dict = {
    "name": ['harry', 'rohan', 'ankit', 'raj'],
    "marks": [95, 34, 56, 99],
    "city": ['rampur', 'dublin', 'kol', 'lucknow']
}

# %%
df =pd.DataFrame(dict)

# %%
df
# Out:
#     name  marks     city
# 0  harry     95   rampur
# 1  rohan     34   dublin
# 2  ankit     56      kol
# 3    raj     99  lucknow

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends.csv',index = False)

# %%
df.head(2)
# Out:
#     name  marks    city
# 0  harry     95  rampur
# 1  rohan     34  dublin

# %%
df.tail(2)
# Out:
#     name  marks     city
# 2  ankit     56      kol
# 3    raj     99  lucknow

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   71.000000
# std    31.379399
# min    34.000000
# 25%    50.500000
# 50%    75.500000
# 75%    96.000000
# max    99.000000

# %%
harry = pd.read_csv('harry.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-313c7e816980> in <cell line: 1>()
# ----> 1 harry = pd.read_csv('harry.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df['marks']
# Out:
# 0    95
# 1    34
# 2    56
# 3    99
# Name: marks, dtype: int64

# %%
df['marks'][0]
# Out:
# 95

# %%
df['marks'][0] = 100
# Out:
# <ipython-input-15-3240b5c8ca6a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['marks'][0] = 100

# %%
df
# Out:
#     name  marks     city
# 0  harry    100   rampur
# 1  rohan     34   dublin
# 2  ankit     56      kol
# 3    raj     99  lucknow

# %%
df.index = ['1st','2nd','3rd','4th']

# %%
df
# Out:
#       name  marks     city
# 1st  harry    100   rampur
# 2nd  rohan     34   dublin
# 3rd  ankit     56      kol
# 4th    raj     99  lucknow

# %%
df2 = pd.DataFrame(np.random.rand(334,5), index = np.arange(334))

# %%
df2
# Out:
#             0         1         2         3         4
# 0    0.199319  0.855079  0.694015  0.003866  0.352821
# 1    0.492199  0.522651  0.541063  0.356798  0.456391
# 2    0.748124  0.628888  0.652660  0.240554  0.390166
# 3    0.763956  0.510532  0.999413  0.113389  0.007309
# 4    0.794697  0.530980  0.529004  0.217906  0.764895
# ..        ...       ...       ...       ...       ...
# 329  0.786063  0.511729  0.588049  0.244693  0.483699
# 330  0.479103  0.094303  0.730678  0.926540  0.109969
# 331  0.057490  0.925545  0.682101  0.899041  0.722590
# 332  0.327842  0.857762  0.925940  0.499429  0.407857
# 333  0.669107  0.220038  0.083173  0.922275  0.842917
#
# [334 rows x 5 columns]

# %%
df2.head()
# Out:
#           0         1         2         3         4
# 0  0.199319  0.855079  0.694015  0.003866  0.352821
# 1  0.492199  0.522651  0.541063  0.356798  0.456391
# 2  0.748124  0.628888  0.652660  0.240554  0.390166
# 3  0.763956  0.510532  0.999413  0.113389  0.007309
# 4  0.794697  0.530980  0.529004  0.217906  0.764895

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#             marks
# count    4.000000
# mean    72.250000
# std     32.724863
# min     34.000000
# 25%     50.500000
# 50%     77.500000
# 75%     99.250000
# max    100.000000

# %%
df.dtypes
# Out:
# name     object
# marks     int64
# city     object
# dtype: object

# %%
df.index
# Out:
# Index(['1st', '2nd', '3rd', '4th'], dtype='object')

# %%
df2.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df2.to_numpy()
# Out:
# array([[0.19931928, 0.85507899, 0.69401527, 0.00386613, 0.35282147],
#        [0.49219876, 0.52265064, 0.54106277, 0.35679789, 0.45639149],
#        [0.74812387, 0.62888788, 0.65265984, 0.24055355, 0.39016606],
#        ...,
#        [0.0574905 , 0.92554523, 0.68210125, 0.89904108, 0.72259048],
#        [0.32784222, 0.85776187, 0.92593976, 0.49942851, 0.40785698],
#        [0.66910736, 0.22003796, 0.08317319, 0.92227479, 0.84291709]])

# %%
df2[0][0] = 5

# %%
df2.head()
# Out:
#           0         1         2         3         4
# 0  5.000000  0.855079  0.694015  0.003866  0.352821
# 1  0.492199  0.522651  0.541063  0.356798  0.456391
# 2  0.748124  0.628888  0.652660  0.240554  0.390166
# 3  0.763956  0.510532  0.999413  0.113389  0.007309
# 4  0.794697  0.530980  0.529004  0.217906  0.764895

# %%
df2.T
# Out:
#         0         1         2         3         4         5         6    \
# 0  5.000000  0.492199  0.748124  0.763956  0.794697  0.576911  0.333180
# 1  0.855079  0.522651  0.628888  0.510532  0.530980  0.526154  0.502715
# 2  0.694015  0.541063  0.652660  0.999413  0.529004  0.277353  0.232032
# 3  0.003866  0.356798  0.240554  0.113389  0.217906  0.453002  0.760017
# 4  0.352821  0.456391  0.390166  0.007309  0.764895  0.283394  0.584213
#
#         7         8         9    ...       324       325       326       327  \
# 0  0.956068  0.850045  0.493367  ...  0.076124  0.860272  0.356381  0.218373
# 1  0.457961  0.710465  0.228965  ...  0.120480  0.515962  0.383092  0.960509
# 2  0.328357  0.347029  0.301705  ...  0.423079  0.584100  0.454850  0.835739
# 3  0.919347  0.163591  0.007745  ...  0.736519  0.638614  0.663303  0.240580
# 4  0.772771  0.398883  0.385143  ...  0.741619  0.624636  0.383444  0.788945
#
#         328       329       330       331       332       333
# ...

# %%
df2.sort_index(axis=0,ascending = False)
# Out:
#             0         1         2         3         4
# 333  0.669107  0.220038  0.083173  0.922275  0.842917
# 332  0.327842  0.857762  0.925940  0.499429  0.407857
# 331  0.057490  0.925545  0.682101  0.899041  0.722590
# 330  0.479103  0.094303  0.730678  0.926540  0.109969
# 329  0.786063  0.511729  0.588049  0.244693  0.483699
# ..        ...       ...       ...       ...       ...
# 4    0.794697  0.530980  0.529004  0.217906  0.764895
# 3    0.763956  0.510532  0.999413  0.113389  0.007309
# 2    0.748124  0.628888  0.652660  0.240554  0.390166
# 1    0.492199  0.522651  0.541063  0.356798  0.456391
# 0    5.000000  0.855079  0.694015  0.003866  0.352821
#
# [334 rows x 5 columns]

# %%
df2[0]
# Out:
# 0      5.000000
# 1      0.492199
# 2      0.748124
# 3      0.763956
# 4      0.794697
#          ...
# 329    0.786063
# 330    0.479103
# 331    0.057490
# 332    0.327842
# 333    0.669107
# Name: 0, Length: 334, dtype: float64

# %%
type(df2[0])
# Out:
# pandas.core.series.Series

# %%
df2.loc[0,0] =666

# %%
df2.head()
# Out:
#             0         1         2         3         4
# 0  666.000000  0.855079  0.694015  0.003866  0.352821
# 1    0.492199  0.522651  0.541063  0.356798  0.456391
# 2    0.748124  0.628888  0.652660  0.240554  0.390166
# 3    0.763956  0.510532  0.999413  0.113389  0.007309
# 4    0.794697  0.530980  0.529004  0.217906  0.764895

# %%
df2.columns = list("ABCDE")

# %%
df2.head()
# Out:
#             A         B         C         D         E
# 0  666.000000  0.855079  0.694015  0.003866  0.352821
# 1    0.492199  0.522651  0.541063  0.356798  0.456391
# 2    0.748124  0.628888  0.652660  0.240554  0.390166
# 3    0.763956  0.510532  0.999413  0.113389  0.007309
# 4    0.794697  0.530980  0.529004  0.217906  0.764895

# %%
df2.loc[0,'A'] = 65

# %%
df2.head()
# Out:
#             A         B         C         D         E      0
# 0  665.000000  0.855079  0.694015  0.003866  0.352821  665.0
# 1    0.492199  0.522651  0.541063  0.356798  0.456391    NaN
# 2    0.748124  0.628888  0.652660  0.240554  0.390166    NaN
# 3    0.763956  0.510532  0.999413  0.113389  0.007309    NaN
# 4    0.794697  0.530980  0.529004  0.217906  0.764895    NaN

# %%
df2.head()
# Out:
#            A         B         C         D         E      0
# 0  65.000000  0.855079  0.694015  0.003866  0.352821  665.0
# 1   0.492199  0.522651  0.541063  0.356798  0.456391    NaN
# 2   0.748124  0.628888  0.652660  0.240554  0.390166    NaN
# 3   0.763956  0.510532  0.999413  0.113389  0.007309    NaN
# 4   0.794697  0.530980  0.529004  0.217906  0.764895    NaN

# %%
df2.drop(0,axis = 1)
# Out:
#              A         B         C         D         E
# 0    65.000000  0.855079  0.694015  0.003866  0.352821
# 1     0.492199  0.522651  0.541063  0.356798  0.456391
# 2     0.748124  0.628888  0.652660  0.240554  0.390166
# 3     0.763956  0.510532  0.999413  0.113389  0.007309
# 4     0.794697  0.530980  0.529004  0.217906  0.764895
# ..         ...       ...       ...       ...       ...
# 329   0.786063  0.511729  0.588049  0.244693  0.483699
# 330   0.479103  0.094303  0.730678  0.926540  0.109969
# 331   0.057490  0.925545  0.682101  0.899041  0.722590
# 332   0.327842  0.857762  0.925940  0.499429  0.407857
# 333   0.669107  0.220038  0.083173  0.922275  0.842917
#
# [334 rows x 5 columns]

# %%
df2.loc[[1.,2],['C','D']]
# Out:
#           C         D
# 1  0.541063  0.356798
# 2  0.652660  0.240554

# %%
df2.loc[:,['C','D']]
# Out:
#             C         D
# 0    0.694015  0.003866
# 1    0.541063  0.356798
# 2    0.652660  0.240554
# 3    0.999413  0.113389
# 4    0.529004  0.217906
# ..        ...       ...
# 329  0.588049  0.244693
# 330  0.730678  0.926540
# 331  0.682101  0.899041
# 332  0.925940  0.499429
# 333  0.083173  0.922275
#
# [334 rows x 2 columns]

# %%
df2.loc[[1.,2],:]
# Out:
#           A         B         C         D         E   0
# 1  0.492199  0.522651  0.541063  0.356798  0.456391 NaN
# 2  0.748124  0.628888  0.652660  0.240554  0.390166 NaN

# %%
df2 = df2.drop(0,axis = 1)

# %%
df2.loc[[1.,2],:]
# Out:
#           A         B         C         D         E
# 1  0.492199  0.522651  0.541063  0.356798  0.456391
# 2  0.748124  0.628888  0.652660  0.240554  0.390166

# %%
df2.loc[df2['A']<0.2]
# Out:
#             A         B         C         D         E
# 14   0.128341  0.101468  0.022575  0.783007  0.499111
# 19   0.105049  0.200919  0.867626  0.069940  0.020039
# 29   0.119468  0.288710  0.168431  0.149120  0.928845
# 31   0.042258  0.503252  0.078530  0.679735  0.875078
# 32   0.060222  0.402045  0.095719  0.018452  0.195011
# ..        ...       ...       ...       ...       ...
# 311  0.086040  0.808428  0.506652  0.411596  0.252275
# 314  0.001853  0.805464  0.131548  0.954177  0.459481
# 315  0.194395  0.378764  0.149756  0.742077  0.034946
# 324  0.076124  0.120480  0.423079  0.736519  0.741619
# 331  0.057490  0.925545  0.682101  0.899041  0.722590
#
# [66 rows x 5 columns]

# %%
df2.loc[(df2['A']<0.2) & (df2['C']>0.2)]
# Out:
#             A         B         C         D         E
# 19   0.105049  0.200919  0.867626  0.069940  0.020039
# 41   0.029299  0.148083  0.860759  0.507377  0.700985
# 48   0.097388  0.874974  0.739370  0.985488  0.630192
# 49   0.006078  0.095498  0.311482  0.894391  0.666765
# 57   0.109518  0.765862  0.887160  0.591829  0.374845
# 58   0.059735  0.703710  0.483392  0.905773  0.804087
# 63   0.064677  0.390439  0.778106  0.072275  0.049537
# 67   0.174881  0.913735  0.663570  0.940377  0.222544
# 72   0.162877  0.785173  0.726018  0.532328  0.300958
# 82   0.076885  0.369439  0.895236  0.235420  0.977794
# 93   0.099963  0.345742  0.343666  0.056705  0.959271
# 95   0.060943  0.145028  0.847805  0.019926  0.465272
# 99   0.030993  0.804703  0.591149  0.407497  0.483586
# 110  0.115773  0.071644  0.319528  0.595996  0.011759
# 126  0.129490  0.161691  0.571190  0.875836  0.022983
# 140  0.028029  0.443844  0.616298  0.906655  0.417713
# ...

# %%
df2.head(2)
# Out:
#            A         B         C         D         E
# 0  65.000000  0.855079  0.694015  0.003866  0.352821
# 1   0.492199  0.522651  0.541063  0.356798  0.456391

# %%
df2.iloc[0,4]
# Out:
# 0.35282147022405996

# %%
df2.iloc[[0,5],[2,3]]
# Out:
#           C         D
# 0  0.694015  0.003866
# 5  0.277353  0.453002

# %%
df2.drop([0])
# Out:
#             A         B         C         D         E
# 1    0.492199  0.522651  0.541063  0.356798  0.456391
# 2    0.748124  0.628888  0.652660  0.240554  0.390166
# 3    0.763956  0.510532  0.999413  0.113389  0.007309
# 4    0.794697  0.530980  0.529004  0.217906  0.764895
# 5    0.576911  0.526154  0.277353  0.453002  0.283394
# ..        ...       ...       ...       ...       ...
# 329  0.786063  0.511729  0.588049  0.244693  0.483699
# 330  0.479103  0.094303  0.730678  0.926540  0.109969
# 331  0.057490  0.925545  0.682101  0.899041  0.722590
# 332  0.327842  0.857762  0.925940  0.499429  0.407857
# 333  0.669107  0.220038  0.083173  0.922275  0.842917
#
# [333 rows x 5 columns]

# %%
df2.drop(['A','C'],axis = 1)
# Out:
#             B         D         E
# 0    0.855079  0.003866  0.352821
# 1    0.522651  0.356798  0.456391
# 2    0.628888  0.240554  0.390166
# 3    0.510532  0.113389  0.007309
# 4    0.530980  0.217906  0.764895
# ..        ...       ...       ...
# 329  0.511729  0.244693  0.483699
# 330  0.094303  0.926540  0.109969
# 331  0.925545  0.899041  0.722590
# 332  0.857762  0.499429  0.407857
# 333  0.220038  0.922275  0.842917
#
# [334 rows x 3 columns]

# %%
df2.drop(['A','C'],axis = 1,inplace = True)

# %%
df2
# Out:
#             B         D         E
# 0    0.855079  0.003866  0.352821
# 1    0.522651  0.356798  0.456391
# 2    0.628888  0.240554  0.390166
# 3    0.510532  0.113389  0.007309
# 4    0.530980  0.217906  0.764895
# ..        ...       ...       ...
# 329  0.511729  0.244693  0.483699
# 330  0.094303  0.926540  0.109969
# 331  0.925545  0.899041  0.722590
# 332  0.857762  0.499429  0.407857
# 333  0.220038  0.922275  0.842917
#
# [334 rows x 3 columns]

# %%
df2.reset_index(drop = True,inplace = True )

# %%
df2
# Out:
#             B         D         E
# 0    0.855079  0.003866  0.352821
# 1    0.522651  0.356798  0.456391
# 2    0.628888  0.240554  0.390166
# 3    0.510532  0.113389  0.007309
# 4    0.530980  0.217906  0.764895
# ..        ...       ...       ...
# 329  0.511729  0.244693  0.483699
# 330  0.094303  0.926540  0.109969
# 331  0.925545  0.899041  0.722590
# 332  0.857762  0.499429  0.407857
# 333  0.220038  0.922275  0.842917
#
# [334 rows x 3 columns]

# %%
df2['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: B, Length: 334, dtype: bool

# %%
df2['B'] = None

# %%
df2
# Out:
#         B         D         E
# 0    None  0.003866  0.352821
# 1    None  0.356798  0.456391
# 2    None  0.240554  0.390166
# 3    None  0.113389  0.007309
# 4    None  0.217906  0.764895
# ..    ...       ...       ...
# 329  None  0.244693  0.483699
# 330  None  0.926540  0.109969
# 331  None  0.899041  0.722590
# 332  None  0.499429  0.407857
# 333  None  0.922275  0.842917
#
# [334 rows x 3 columns]

# %%
df2.loc[:,'B'] = True
# Out:
# <ipython-input-89-6835f165dd74>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df2.loc[:,'B'] = True

# %%
df2
# Out:
#         B         D         E
# 0    True  0.003866  0.352821
# 1    True  0.356798  0.456391
# 2    True  0.240554  0.390166
# 3    True  0.113389  0.007309
# 4    True  0.217906  0.764895
# ..    ...       ...       ...
# 329  True  0.244693  0.483699
# 330  True  0.926540  0.109969
# 331  True  0.899041  0.722590
# 332  True  0.499429  0.407857
# 333  True  0.922275  0.842917
#
# [334 rows x 3 columns]

# %%
df1 = pd.DataFrame({"name": ['Alfred','snowy','john'],
                   "toy":['app','jaa','hehe'],
                   "born": [pd.NaT,pd.Timestamp("4-4-16"),pd.NaT]})

# %%
df1
# Out:
#      name   toy       born
# 0  Alfred   app        NaT
# 1   snowy   jaa 2016-04-04
# 2    john  hehe        NaT

# %%
df1.dropna()
# Out:
#     name  toy       born
# 1  snowy  jaa 2016-04-04

# %%
df1.dropna(how ='all')
# Out:
#      name   toy       born
# 0  Alfred   app        NaT
# 1   snowy   jaa 2016-04-04
# 2    john  hehe        NaT
